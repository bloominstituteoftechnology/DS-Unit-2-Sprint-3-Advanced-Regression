# %% [markdown]
# # Data Science Unit 4 Sprint Challenge 1 — Tree Ensembles

# %% [markdown]
# ### Chicago Food Inspections
#
# For this Sprint Challenge, you'll use a dataset with information from inspections of restaurants and other food establishments in Chicago from January 1, 2010 to the present.
#
# [See this PDF](https://data.cityofchicago.org/api/assets/BAD5301B-681A-4202-9D25-51B2CAE672FF) for descriptions of the data elements included in this dataset.
#
# According to [Chicago Department of Public Health — Food Protection Services](https://www.chicago.gov/city/en/depts/cdph/provdrs/healthy_restaurants/svcs/food-protection-services.html), "Chicago is home to 16,000 food establishments like restaurants, grocery stores, bakeries, wholesalers, lunchrooms, mobile food vendors and more. Our business is food safety and sanitation with one goal, to prevent the spread of food-borne disease. We do this by inspecting food businesses, responding to complaints and food recalls."

# %% [markdown]
# #### Your challenge: Predict whether inspections failed
#
# The target is the `Fail` column.
#
# - When the food establishment failed the inspection, the target is `1`.
# - When the establishment passed, the target is `0`.

# %% [markdown]
# #### Run this cell to load the data:

# %%
import pandas as pd

train_url = 'https://drive.google.com/uc?export=download&id=13_tP9JpLcZHSPVpWcua4t2rY44K_s4H5'
test_url  = 'https://drive.google.com/uc?export=download&id=1GkDHjsiGrzOXoF_xcYjdzBTSjOIi3g5a'

train = pd.read_csv(train_url)
test  = pd.read_csv(test_url)

assert train.shape == (51916, 17)
assert test.shape  == (17306, 17)

# %% [markdown]
# ## Part 1: Preprocessing¶
#
# You may choose which features you want to use, and whether/how you will preprocess them. You may use any tools and techniques for categorical encoding. (Pandas, category_encoders, sklearn.preprocessing, or any other library.)
#
# To earn a score of 3 for this part, engineer new features, and use any alternative categorical encoding instead of One-Hot or Ordinal/Label encoding.

# %%
train.head()
# Out:
#    Inspection ID                               DBA Name  \
# 0        2088270            TOM YUM RICE & NOODLE, INC.
# 1         555268  FILLING STATION  & CONVENIENCE  STORE
# 2        1751394                               A P DELI
# 3        1763905           FRANK'S CHICAGO SHRIMP HOUSE
# 4         453326                                MORRILL
#
#                                 AKA Name  License #  Facility Type  \
# 0                           TOM YUM CAFE  2354911.0     Restaurant
# 1  FILLING STATION  & CONVENIENCE  STORE  1044901.0  Grocery Store
# 2                               A P DELI    47405.0     Restaurant
# 3           FRANK'S CHICAGO SHRIMP HOUSE     6414.0     Restaurant
# 4                                MORRILL    24571.0         School
#
#               Risk                       Address     City State      Zip  \
# 0    Risk 1 (High)                  608 W BARRY   CHICAGO    IL  60657.0
# 1     Risk 3 (Low)      6646-6658 S WESTERN AVE   CHICAGO    IL  60636.0
# 2    Risk 1 (High)               2025 E 75TH ST   CHICAGO    IL  60649.0
# 3  Risk 2 (Medium)            4459 S ARCHER AVE   CHICAGO    IL  60632.0
# 4    Risk 1 (High)  6011 S Rockwell (2600W) AVE   CHICAGO    IL  60629.0
#
#        Inspection Date          Inspection Type  \
# 0  2017-09-15T00:00:00                  Canvass
# 1  2011-10-20T00:00:00  Complaint Re-Inspection
# 2  2016-04-05T00:00:00    Canvass Re-Inspection
# 3  2016-04-29T00:00:00                  Canvass
# 4  2011-01-10T00:00:00                  Canvass
#
#                                           Violations   Latitude  Longitude  \
# 0  3. POTENTIALLY HAZARDOUS FOOD MEETS TEMPERATUR...  41.938007 -87.644755
# 1  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.772402 -87.683603
# 2  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.758779 -87.575054
# 3  38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS...  41.812181 -87.707125
# 4  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...        NaN        NaN
#
#                                             Location  Fail
# 0  {'longitude': '-87.6447545707008', 'latitude':...     1
# 1  {'longitude': '-87.68360273081268', 'latitude'...     0
# 2  {'longitude': '-87.57505446746121', 'latitude'...     0
# 3  {'longitude': '-87.70712481334274', 'latitude'...     0
# 4                                                NaN     0

# %%
test.head()
# Out:
#    Inspection ID                                     DBA Name  \
# 0         114835                                   7 - ELEVEN
# 1        1575555                      TAQUERIA LOS GALLOS INC
# 2         671061                              TROTTER'S TO GO
# 3        1965844                                BIG G'S PIZZA
# 4        1751669  SOUTH CENTRAL COMMUNITY SERVICES ELEMENTARY
#
#                                       AKA Name  License #  Facility Type  \
# 0                                   7 - ELEVEN    46907.0  Grocery Store
# 1                          TAQUERIA LOS GALLOS  1044860.0     Restaurant
# 2                              TROTTER'S TO GO  1092634.0     Restaurant
# 3                                BIG G'S PIZZA  2334691.0     Restaurant
# 4  SOUTH CENTRAL COMMUNITY SERVICES ELEMENTARY  3491970.0         School
#
#               Risk                Address     City State      Zip  \
# 0  Risk 2 (Medium)        600 S DEARBORN   CHICAGO    IL  60605.0
# 1    Risk 1 (High)   4209-4211 W 26TH ST   CHICAGO    IL  60623.0
# 2    Risk 1 (High)  1337 W FULLERTON AVE   CHICAGO    IL  60614.0
# 3    Risk 1 (High)      1132 W TAYLOR ST   CHICAGO    IL  60607.0
# 4  Risk 2 (Medium)           1021 E 83RD   CHICAGO    IL  60619.0
#
#        Inspection Date        Inspection Type  \
# 0  2011-03-22T00:00:00                Canvass
# 1  2015-09-15T00:00:00                Canvass
# 2  2012-03-02T00:00:00                Canvass
# 3  2016-10-04T00:00:00  Canvass Re-Inspection
# 4  2016-04-08T00:00:00                Canvass
#
#                                           Violations   Latitude  Longitude  \
# 0  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...  41.874481 -87.629357
# 1  30. FOOD IN ORIGINAL CONTAINER, PROPERLY LABEL...  41.844070 -87.729807
# 2  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  41.925128 -87.662041
# 3  14. PREVIOUS SERIOUS VIOLATION CORRECTED, 7-42...  41.869546 -87.655501
# 4  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.743933 -87.599291
#
#                                             Location  Fail
# 0  {'longitude': '-87.62935653990546', 'latitude'...     0
# 1  {'longitude': '-87.72980747367433', 'latitude'...     0
# 2  {'longitude': '-87.66204067083224', 'latitude'...     0
# 3  {'longitude': '-87.65550098867566', 'latitude'...     1
# 4  {'longitude': '-87.59929083361996', 'latitude'...     1

# %% [markdown]
# ### Concatenate the training and testing sets to easy data manipulation

# %%
df_main = pd.concat([train,test])

# %%
df_main.shape
# Out:
# (69222, 17)

# %%
# the orignial shapes of the files
"train 51916 test 17306: " + str(51916 + 17306)
# Out:
# 'train 51916 test 17306: 69222'

# %%
# lot's of NaNs in different columns
df_main.isna().sum()
# Out:
# Inspection ID          0
# DBA Name               0
# AKA Name             845
# License #              7
# Facility Type        311
# Risk                  19
# Address                0
# City                  71
# State                 12
# Zip                   34
# Inspection Date        0
# Inspection Type        1
# Violations         12935
# Latitude             259
# Longitude            259
# Location             259
# Fail                   0
# dtype: int64

# %%
df_main.columns
# Out:
# Index(['Inspection ID', 'DBA Name', 'AKA Name', 'License #', 'Facility Type',
#        'Risk', 'Address', 'City', 'State', 'Zip', 'Inspection Date',
#        'Inspection Type', 'Violations', 'Latitude', 'Longitude', 'Location',
#        'Fail'],
#       dtype='object')

# %%
## Let's delete the columns with the same/redundant info
df_select_cols = df_main.drop(columns=['DBA Name','Address', 'City', 'State','Location'])

# %%
df_select_cols.shape
# Out:
# (69222, 12)

# %%
df_select_cols.isna().sum()
# Out:
# Inspection ID          0
# AKA Name             845
# License #              7
# Facility Type        311
# Risk                  19
# Zip                   34
# Inspection Date        0
# Inspection Type        1
# Violations         12935
# Latitude             259
# Longitude            259
# Fail                   0
# dtype: int64

# %%
#check the data type 
df_select_cols.dtypes
# Out:
# Inspection ID        int64
# AKA Name            object
# License #          float64
# Facility Type       object
# Risk                object
# Zip                float64
# Inspection Date     object
# Inspection Type     object
# Violations          object
# Latitude           float64
# Longitude          float64
# Fail                 int64
# dtype: object

# %%
df_select_cols.head()
# Out:
#    Inspection ID                               AKA Name  License #  \
# 0        2088270                           TOM YUM CAFE  2354911.0
# 1         555268  FILLING STATION  & CONVENIENCE  STORE  1044901.0
# 2        1751394                               A P DELI    47405.0
# 3        1763905           FRANK'S CHICAGO SHRIMP HOUSE     6414.0
# 4         453326                                MORRILL    24571.0
#
#    Facility Type             Risk      Zip      Inspection Date  \
# 0     Restaurant    Risk 1 (High)  60657.0  2017-09-15T00:00:00
# 1  Grocery Store     Risk 3 (Low)  60636.0  2011-10-20T00:00:00
# 2     Restaurant    Risk 1 (High)  60649.0  2016-04-05T00:00:00
# 3     Restaurant  Risk 2 (Medium)  60632.0  2016-04-29T00:00:00
# 4         School    Risk 1 (High)  60629.0  2011-01-10T00:00:00
#
#            Inspection Type                                         Violations  \
# 0                  Canvass  3. POTENTIALLY HAZARDOUS FOOD MEETS TEMPERATUR...
# 1  Complaint Re-Inspection  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
# 2    Canvass Re-Inspection  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...
# 3                  Canvass  38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS...
# 4                  Canvass  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...
#
#     Latitude  Longitude  Fail
# 0  41.938007 -87.644755     1
# 1  41.772402 -87.683603     0
# 2  41.758779 -87.575054     0
# 3  41.812181 -87.707125     0
# 4        NaN        NaN     0

# %% [markdown]
# ## Import Columns: let's take care of the strings
# ## Not Hot encoding these two columns

# %%
#let's split the string so that we keep only the violation number
df_select_cols['Violations_int'] = df_select_cols['Violations'].str.split('.').str[0]

# %%
#let's extract the digits representing the risk category
df_select_cols['risk_int'] = df_select_cols['Risk'].str.extract('(\d+)', expand=False)

# %%
#delete the orignal columns
df_select_cols = df_select_cols.drop(columns=['Violations', 'Risk'])

# %%
df_select_cols.head()
# Out:
#    Inspection ID                               AKA Name  License #  \
# 0        2088270                           TOM YUM CAFE  2354911.0
# 1         555268  FILLING STATION  & CONVENIENCE  STORE  1044901.0
# 2        1751394                               A P DELI    47405.0
# 3        1763905           FRANK'S CHICAGO SHRIMP HOUSE     6414.0
# 4         453326                                MORRILL    24571.0
#
#    Facility Type      Zip      Inspection Date          Inspection Type  \
# 0     Restaurant  60657.0  2017-09-15T00:00:00                  Canvass
# 1  Grocery Store  60636.0  2011-10-20T00:00:00  Complaint Re-Inspection
# 2     Restaurant  60649.0  2016-04-05T00:00:00    Canvass Re-Inspection
# 3     Restaurant  60632.0  2016-04-29T00:00:00                  Canvass
# 4         School  60629.0  2011-01-10T00:00:00                  Canvass
#
#     Latitude  Longitude  Fail Violations_int risk_int
# 0  41.938007 -87.644755     1              3        1
# 1  41.772402 -87.683603     0             32        3
# 2  41.758779 -87.575054     0             35        1
# 3  41.812181 -87.707125     0             38        2
# 4        NaN        NaN     0             34        1

# %%
df_select_cols['Violations_int'] =df_select_cols['Violations_int'].astype(float)

# %%
df_select_cols['risk_int'] =df_select_cols['risk_int'].astype(float)

# %%
df_select_cols.isna().sum()
# Out:
# Inspection ID          0
# AKA Name             845
# License #              7
# Facility Type        311
# Zip                   34
# Inspection Date        0
# Inspection Type        1
# Latitude             259
# Longitude            259
# Fail                   0
# Violations_int     12935
# risk_int              19
# dtype: int64

# %%
df_select_cols.dtypes
# Out:
# Inspection ID        int64
# AKA Name            object
# License #          float64
# Facility Type       object
# Zip                float64
# Inspection Date     object
# Inspection Type     object
# Latitude           float64
# Longitude          float64
# Fail                 int64
# Violations_int     float64
# risk_int           float64
# dtype: object

# %% [markdown]
# ### filling all the int columsn with mean values

# %%
def mean_fill_na(X):
    for col in X:
        if X[col].dtypes == int or X[col].dtypes ==float:
            if X[col].isnull().sum()>0:
                X[col]=X[col].fillna(X[col].mean())
            
    return X

# %%
mean_fill_na(df_select_cols)
# Out:
#        Inspection ID                                    AKA Name  License #  \
# 0            2088270                                TOM YUM CAFE  2354911.0
# 1             555268       FILLING STATION  & CONVENIENCE  STORE  1044901.0
# 2            1751394                                    A P DELI    47405.0
# 3            1763905                FRANK'S CHICAGO SHRIMP HOUSE     6414.0
# 4             453326                                     MORRILL    24571.0
# 5            1725221  LAKEVIEW REHABILITATION AND NURSING CENTER  2245580.0
# 6            1981372                             GOLD COAST DOGS    32318.0
# 7            1072403                                         NaN  2241028.0
# 8            1464616                              THE PUMPING CO  1544937.0
# 9             583261                         YUMMY YUMMY NOODLES  2098003.0
# 10           1516695                               PETE'S MARKET    36823.0
# 11            166332                          GRAND TRIPLE CROWN  1878843.0
# 12           1982990                       MARK TWAIN ELEMENTARY    25661.0
# 13            635040                               MS EGGROLL #2  2089284.0
# 14           1445382                POLK & WESTERN HOT DOG STAND  2362987.0
# 15           2071751                               VICEROY HOTEL  2535449.0
# 16           1395548                          JIMMY JOHN'S CLARK  1768647.0
# 17            422255                            MINGHIN  CUISINE  2031974.0
# 18           1464592                                         KFC  1695369.0
# 19           1966651                                    Forum 55  1472957.0
# 20            580400                          ROTHSCHILD LIQUORS    21041.0
# 21           1473446                           EL NUEVO MEXICANO     1525.0
# 22           2232615                                MILD 2 SPICY  2536509.0
# 23           2151190                                    WINGSTOP  2253834.0
# 24           1631721                                   VEGAN NOW  2447002.0
# 25           1977206                  THE GUNDIS KURDISH KITCHEN  2488493.0
# 26           1559966                                   BAR LOUIE  2026594.0
# 2           1.0
# 3           2.0
# 4           1.0
# 5           1.0
# 6           2.0
# 7           1.0
# 8           1.0
# 9           1.0
# 10          1.0
# 11          1.0
# 12          1.0
# 13          1.0
# 14          1.0
# 15          3.0
# 16          1.0
# 17          1.0
# 18          1.0
# 19          1.0
# 20          3.0
# 21          1.0
# 22          1.0
# 23          1.0
# 24          2.0
# 25          1.0
# 26          1.0
# 27          1.0
# 28          1.0
# 29          2.0
# ...         ...
# 17276       1.0
# 17277       1.0
# 17278       1.0
# 17279       1.0
# 17280       1.0
# 17281       2.0
# 17282       1.0
# 17283       1.0
# 17284       1.0
# 17285       1.0
# 17286       1.0
# 17287       2.0
# 17288       1.0
# 17289       1.0
# 17290       1.0
# 17291       2.0
# 17292       1.0
# 17293       1.0
# 17294       1.0
# 17295       1.0
# 17296       1.0
# 17297       1.0
# 17298       1.0
# 17299       1.0
# 17300       1.0
# 17301       2.0
# 17302       1.0
# 17303       1.0
# 17304       1.0
# 17305       2.0
#
# [69222 rows x 12 columns]

# %%
df_select_cols.isna().sum()
# Out:
# Inspection ID        0
# AKA Name           845
# License #            0
# Facility Type      311
# Zip                  0
# Inspection Date      0
# Inspection Type      1
# Latitude             0
# Longitude            0
# Fail                 0
# Violations_int       0
# risk_int             0
# dtype: int64

# %% [markdown]
# ### Categorical Columns: Let's fill them with mode

# %%
# all categorical columns can be filled with mode
df_no_nans = df_select_cols.fillna(df_select_cols.mode().iloc[0])

# %%
df_no_nans.isna().sum()
# Out:
# Inspection ID      0
# AKA Name           0
# License #          0
# Facility Type      0
# Zip                0
# Inspection Date    0
# Inspection Type    0
# Latitude           0
# Longitude          0
# Fail               0
# Violations_int     0
# risk_int           0
# dtype: int64

# %%
#I like keeping a copy of hte cleaned df before converting
#it through any dummy converter
df = df_no_nans.copy()

# %%
df.head()
# Out:
#    Inspection ID                               AKA Name  License #  \
# 0        2088270                           TOM YUM CAFE  2354911.0
# 1         555268  FILLING STATION  & CONVENIENCE  STORE  1044901.0
# 2        1751394                               A P DELI    47405.0
# 3        1763905           FRANK'S CHICAGO SHRIMP HOUSE     6414.0
# 4         453326                                MORRILL    24571.0
#
#    Facility Type      Zip      Inspection Date          Inspection Type  \
# 0     Restaurant  60657.0  2017-09-15T00:00:00                  Canvass
# 1  Grocery Store  60636.0  2011-10-20T00:00:00  Complaint Re-Inspection
# 2     Restaurant  60649.0  2016-04-05T00:00:00    Canvass Re-Inspection
# 3     Restaurant  60632.0  2016-04-29T00:00:00                  Canvass
# 4         School  60629.0  2011-01-10T00:00:00                  Canvass
#
#     Latitude  Longitude  Fail Violations_int risk_int
# 0  41.938007 -87.644755     1              3        1
# 1  41.772402 -87.683603     0             32        3
# 2  41.758779 -87.575054     0             35        1
# 3  41.812181 -87.707125     0             38        2
# 4  41.879555 -87.676658     0             34        1

# %% [markdown]
# ###  Sklearn Label encoder for the catergoies not so important

# %%
from sklearn.preprocessing import LabelEncoder
def dummyEncode(df):
        columnsToEncode = list(df.select_dtypes(include=['category','object']))
        le = LabelEncoder()
        for feature in columnsToEncode:
# 9           18.000000       1.0
# 10          34.000000       1.0
# 11          27.616341       1.0
# 12          27.616341       1.0
# 13          31.000000       1.0
# 14          38.000000       1.0
# 15          27.616341       3.0
# 16          32.000000       1.0
# 17          18.000000       1.0
# 18          29.000000       1.0
# 19          32.000000       1.0
# 20          16.000000       3.0
# 21          30.000000       1.0
# 22           3.000000       1.0
# 23          29.000000       1.0
# 24          27.616341       2.0
# 25           9.000000       1.0
# 26          32.000000       1.0
# 27          14.000000       1.0
# 28          27.616341       1.0
# 29          27.616341       2.0
# ...               ...       ...
# 17276       32.000000       1.0
# 17277       38.000000       1.0
# 17278       32.000000       1.0
# 17279       29.000000       1.0
# 17280       32.000000       1.0
# 17281       27.616341       2.0
# 17282       32.000000       1.0
# 17283       34.000000       1.0
# 17284       29.000000       1.0
# 17285       27.616341       1.0
# 17286       33.000000       1.0
# 17287       18.000000       2.0
# 17288       35.000000       1.0
# 17289       27.616341       1.0
# 17290       33.000000       1.0
# 17291       38.000000       2.0
# 17292       33.000000       1.0
# 17293        3.000000       1.0
# 17294       32.000000       1.0
# 17295       32.000000       1.0
# 17296       18.000000       1.0
# 17297        2.000000       1.0
# 17298       31.000000       1.0
# 17299       31.000000       1.0
# 17300       32.000000       1.0
# 17301       34.000000       2.0
# 17302        2.000000       1.0
# 17303       30.000000       1.0
# 17304       32.000000       1.0
# 17305       33.000000       2.0
#
# [69222 rows x 12 columns]

# %% [markdown]
# ## Part 2: Modeling
# Fit a Random Forest or Gradient Boosting model with the train set. (You may use scikit-learn, xgboost, or any other library.) Use cross-validation to estimate an ROC AUC validation score.
#
# Use your model to predict probabilities for the test set. Get an ROC AUC test score >= 0.60.
#
# To earn a score of 3 for this part, get an ROC AUC test score >= 0.70.

# %% [markdown]
# ### Spliting training and test df back into original shape

# %%
df_X = df_no_nans[:-17306]
df_X_test = df_no_nans[-17306:]

# %%
df_no_nans.columns
# Out:
# Index(['Inspection ID', 'AKA Name', 'License #', 'Facility Type', 'Zip',
#        'Inspection Date', 'Inspection Type', 'Latitude', 'Longitude', 'Fail',
#        'Violations_int', 'risk_int'],
#       dtype='object')

# %%
X = df_X.drop(columns=['Fail', 'Inspection Date', 'Latitude', 'Longitude'])
y = df_X['Fail']

# %%
X_test = df_X_test.drop(columns=['Fail', 'Inspection Date', 'Latitude', 'Longitude'])
y_test = df_X_test['Fail']

# %%
X.shape, y.shape, X_test.shape, y_test.shape
# Out:
# ((51916, 8), (51916,), (17306, 8), (17306,))

# %%
y.shape
# Out:
# (51916,)

# %%
df_no_nans.Fail.value_counts(normalize=True)
# Out:
# 0    0.741397
# 1    0.258603
# Name: Fail, dtype: float64

# %% [markdown]
# ## Random Forest: choosing parameters and cross-validation scores

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import make_pipeline

X = df_X.drop(columns=['Fail','Inspection Date', 'Latitude', 'Longitude'])
y = df_X['Fail']

pipe = make_pipeline(RandomForestClassifier(n_estimators=100, 
                            class_weight='balanced', 
                            min_samples_leaf=0.005, 
                            oob_score=True, n_jobs=-1)
                    )

cross_val_score(pipe, X, y, cv=5, scoring='roc_auc', verbose=10)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  ................................................................
# [CV] ....................... , score=0.9920395913725258, total=   1.4s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [CV] ....................... , score=0.9918885313508599, total=   1.4s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.8s remaining:    0.0s
# [CV] ....................... , score=0.9892281145844067, total=   1.4s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.3s remaining:    0.0s
# [CV] ....................... , score=0.9902342043424178, total=   1.4s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    5.6s remaining:    0.0s
# [CV] ....................... , score=0.9908055636594284, total=   1.4s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    7.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    7.1s finished
# array([0.99203959, 0.99188853, 0.98922811, 0.9902342 , 0.99080556])

# %% [markdown]
# ### Model Fitting and ROC AUC

# %%
 pipe.fit(X, y)
y_pred_proba = pipe.named_steps['randomforestclassifier'].oob_decision_function_[:, 1]
print('ROC AUC, OOB:', roc_auc_score(y, y_pred_proba))
# Out:
# ROC AUC, OOB: 0.990241188896948

# %%
y_pred_proba = pipe.named_steps['randomforestclassifier'].oob_decision_function_[:, 1]
print('ROC AUC, Out-of-Bag estimate:', roc_auc_score(y, y_pred_proba))
# Out:
# ROC AUC, Out-of-Bag estimate: 0.990241188896948

# %% [markdown]
# ### Predicting y probabilities using test data

# %%
y_pred = pipe.predict_proba(X_test)[:,1]

# %%
y_pred
# Out:
# array([0.10558804, 0.06405768, 0.05909596, ..., 0.22056761, 0.1260628 ,
#        0.09198276])

# %%
print('Validation ROC AUC:', roc_auc_score(y_test, y_pred))
# Out:
# Validation ROC AUC: 0.9910549041275298

# %% [markdown]
# ### Just wanted to check the class prediction and classification report

# %%
y_prediction = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report
print(classification_report(y_test, y_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     12831
#            1       0.93      0.91      0.92      4475
#
#    micro avg       0.96      0.96      0.96     17306
#    macro avg       0.95      0.94      0.95     17306
# weighted avg       0.96      0.96      0.96     17306

# %% [markdown]
# ### Gradient Boosting Classifier

# %%
# %%time
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

encoder = ce.OrdinalEncoder()
X_train = encoder.fit_transform(X)
X_test = encoder.transform(X_test)
gb = GradientBoostingClassifier()
gb.fit(X, y)
y_pred_proba = gb.predict_proba(X_test)[:,1]
print('Validation ROC AUC:', roc_auc_score(y_test, y_pred_proba))
# Out:
# Validation ROC AUC: 0.9938653810233509
# CPU times: user 3.33 s, sys: 4 ms, total: 3.34 s
# Wall time: 3.41 s

# %% [markdown]
# ## Part 3: Visualization
# Make one visualization for model interpretation. (You may use any libraries.) Choose one of these types:
#
# Feature Importances
# Permutation Importances
# Partial Dependence Plot
# To earn a score of 3 for this part, make at least two of these visualization types.

# %% [markdown]
# ## Show feature importance

# %%
import matplotlib.pyplot as plt
def show_feature_importance(
pipe, X, y, estimator_name='randomforestclassifier',
n=20, figsize=(8,8)):
    
    #pipe must not change dimensions of X dataframe
    pipe.fit(X,y)
    
    importances = pd.Series(
    pipe.named_steps[estimator_name].feature_importances_,
    X.columns)
    
    top_n = importances.sort_values(ascending=False)[:n]
    
    plt.figure(figsize=figsize)
    top_n.sort_values().plot.barh(color='grey')


show_feature_importance(pipe, X, y)

# %%
# !pip install eli5
# Out:
# Collecting eli5
#   Using cached https://files.pythonhosted.org/packages/8d/c8/04bed18dcce1d927b0dd5fc3425777354b714d2e62d60ae301928b5a5bf8/eli5-0.8.1-py2.py3-none-any.whl
# Collecting tabulate>=0.7.7 (from eli5)
#   Using cached https://files.pythonhosted.org/packages/c2/fd/202954b3f0eb896c53b7b6f07390851b1fd2ca84aa95880d7ae4f434c4ac/tabulate-0.8.3.tar.gz
# Requirement already satisfied: scipy in /home/mishraka/anaconda3/lib/python3.6/site-packages (from eli5) (1.1.0)
# Collecting typing (from eli5)
#   Using cached https://files.pythonhosted.org/packages/4a/bd/eee1157fc2d8514970b345d69cb9975dcd1e42cd7e61146ed841f6e68309/typing-3.6.6-py3-none-any.whl
# Requirement already satisfied: numpy>=1.9.0 in /home/mishraka/anaconda3/lib/python3.6/site-packages (from eli5) (1.15.4)
# Requirement already satisfied: six in /home/mishraka/anaconda3/lib/python3.6/site-packages (from eli5) (1.12.0)
# Requirement already satisfied: jinja2 in /home/mishraka/anaconda3/lib/python3.6/site-packages (from eli5) (2.10)
# Requirement already satisfied: attrs>16.0.0 in /home/mishraka/anaconda3/lib/python3.6/site-packages (from eli5) (19.1.0)
# Collecting graphviz (from eli5)
#   Using cached https://files.pythonhosted.org/packages/1f/e2/ef2581b5b86625657afd32030f90cf2717456c1d2b711ba074bf007c0f1a/graphviz-0.10.1-py2.py3-none-any.whl
# Requirement already satisfied: scikit-learn>=0.18 in /home/mishraka/anaconda3/lib/python3.6/site-packages (from eli5) (0.20.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/mishraka/anaconda3/lib/python3.6/site-packages (from jinja2->eli5) (1.1.1)
# Building wheels for collected packages: tabulate
#   Building wheel for tabulate (setup.py) ... done
#   Stored in directory: /home/mishraka/.cache/pip/wheels/2b/67/89/414471314a2d15de625d184d8be6d38a03ae1e983dbda91e84
# Successfully built tabulate
# Installing collected packages: tabulate, typing, graphviz, eli5
# Successfully installed eli5-0.8.1 graphviz-0.10.1 tabulate-0.8.3 typing-3.6.6

# %%
# !pip install category_encoders
# Out:
# Collecting category_encoders
#   Using cached https://files.pythonhosted.org/packages/f7/d3/82a4b85a87ece114f6d0139d643580c726efa45fa4db3b81aed38c0156c5/category_encoders-1.3.0-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.11.1 in /home/mishraka/anaconda3/lib/python3.6/site-packages (from category_encoders) (1.15.4)
# Requirement already satisfied: pandas>=0.20.1 in /home/mishraka/anaconda3/lib/python3.6/site-packages (from category_encoders) (0.24.2)
# Requirement already satisfied: scipy>=0.17.0 in /home/mishraka/anaconda3/lib/python3.6/site-packages (from category_encoders) (1.1.0)
# Requirement already satisfied: statsmodels>=0.6.1 in /home/mishraka/anaconda3/lib/python3.6/site-packages (from category_encoders) (0.9.0)
# Requirement already satisfied: scikit-learn>=0.17.1 in /home/mishraka/anaconda3/lib/python3.6/site-packages (from category_encoders) (0.20.1)
# Requirement already satisfied: patsy>=0.4.1 in /home/mishraka/anaconda3/lib/python3.6/site-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: pytz>=2011k in /home/mishraka/anaconda3/lib/python3.6/site-packages (from pandas>=0.20.1->category_encoders) (2018.9)
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/mishraka/anaconda3/lib/python3.6/site-packages (from pandas>=0.20.1->category_encoders) (2.8.0)
# Requirement already satisfied: six in /home/mishraka/anaconda3/lib/python3.6/site-packages (from patsy>=0.4.1->category_encoders) (1.12.0)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-1.3.0

# %% [markdown]
# ## Permutation importantce

# %%
import eli5
from eli5.sklearn import PermutationImportance
import category_encoders as ce

encoder = ce.OrdinalEncoder()
X_train_transformed = encoder.fit_transform(X)

model = RandomForestClassifier(
    n_estimators=100,
    class_weight='balanced',
    min_samples_leaf=0.005,
    n_jobs=-1)

model.fit(X_train_transformed, y)
permuter = PermutationImportance(model, scoring='roc_auc', n_iter=1, cv='prefit')
permuter.fit(X_train_transformed, y)
# Out:
# PermutationImportance(cv='prefit',
#            estimator=RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=0.005,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=-1, oob_score=False,
#             random_state=None, verbose=0, warm_start=False),
#            n_iter=1, random_state=None, refit=True, scoring='roc_auc')

# %%
eli5.show_weights(permuter, top=None, feature_names=X_train_transformed.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4281
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Violations_int
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.89%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0172
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Inspection Type
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.14%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0048
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Inspection Date
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.33%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0034
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Inspection ID
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.33%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0034
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 License #
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.81%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0005
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Latitude
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.86%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Longitude
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.89%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Zip
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Facility Type
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 risk_int
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AKA Name
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>
