# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('fma_metadata/tracks.csv', header = None)

# %%
df.head()
# Out:
#         NaN  comments         date_created        date_released  engineer  \
# 0       NaN     album                album                album     album
# 1       NaN  comments         date_created        date_released  engineer
# 2  track_id       NaN                  NaN                  NaN       NaN
# 3         2         0  2008-11-26 01:44:45  2009-01-05 00:00:00       NaN
# 4         3         0  2008-11-26 01:44:45  2009-01-05 00:00:00       NaN
#
#    favorites     id  information  listens  producer      ...       \
# 0      album  album        album    album     album      ...
# 1  favorites     id  information  listens  producer      ...
# 2        NaN    NaN          NaN      NaN       NaN      ...
# 3          4      1      <p></p>     6073       NaN      ...
# 4          4      1      <p></p>     6073       NaN      ...
#
#    information  interest  language_code  \
# 0        track     track          track
# 1  information  interest  language_code
# 2          NaN       NaN            NaN
# 3          NaN      4656             en
# 4          NaN      1470             en
#
#                                              license  listens  lyricist  \
# 0                                              track    track     track
# 1                                            license  listens  lyricist
# 2                                                NaN      NaN       NaN
# 3  Attribution-NonCommercial-ShareAlike 3.0 Inter...     1293       NaN
# 4  Attribution-NonCommercial-ShareAlike 3.0 Inter...      514       NaN
#
#    number  publisher   tags         title
# 0   track      track  track         track
# 1  number  publisher   tags         title
# 2     NaN        NaN    NaN           NaN
# 3       3        NaN     []          Food
# 4       4        NaN     []  Electric Ave
#
# [5 rows x 53 columns]

# %%
names = list(df.loc[1,:])

# %%
names[0] = 'track_id'

# %%
names[0]
# Out:
# 'track_id'

# %%
df.columns = names

# %%
df.head()
# Out:
#    track_id  comments         date_created        date_released  engineer  \
# 0       NaN     album                album                album     album
# 1       NaN  comments         date_created        date_released  engineer
# 2  track_id       NaN                  NaN                  NaN       NaN
# 3         2         0  2008-11-26 01:44:45  2009-01-05 00:00:00       NaN
# 4         3         0  2008-11-26 01:44:45  2009-01-05 00:00:00       NaN
#
#    favorites     id  information  listens  producer      ...       \
# 0      album  album        album    album     album      ...
# 1  favorites     id  information  listens  producer      ...
# 2        NaN    NaN          NaN      NaN       NaN      ...
# 3          4      1      <p></p>     6073       NaN      ...
# 4          4      1      <p></p>     6073       NaN      ...
#
#    information  interest  language_code  \
# 0        track     track          track
# 1  information  interest  language_code
# 2          NaN       NaN            NaN
# 3          NaN      4656             en
# 4          NaN      1470             en
#
#                                              license  listens  lyricist  \
# 0                                              track    track     track
# 1                                            license  listens  lyricist
# 2                                                NaN      NaN       NaN
# 3  Attribution-NonCommercial-ShareAlike 3.0 Inter...     1293       NaN
# 4  Attribution-NonCommercial-ShareAlike 3.0 Inter...      514       NaN
#
#    number  publisher   tags         title
# 0   track      track  track         track
# 1  number  publisher   tags         title
# 2     NaN        NaN    NaN           NaN
# 3       3        NaN     []          Food
# 4       4        NaN     []  Electric Ave
#
# [5 rows x 53 columns]

# %%
df = df.drop(df.index[[0,1,2]])

# %%
ddf = df.reset_index(drop=True)

# %%
ddf.head()
# Out:
#   track_id comments         date_created        date_released engineer  \
# 0        2        0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 1        3        0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 2        5        0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 3       10        0  2008-11-26 01:45:08  2008-02-06 00:00:00      NaN
# 4       20        0  2008-11-26 01:45:05  2009-01-06 00:00:00      NaN
#
#   favorites id                                information listens producer  \
# 0         4  1                                    <p></p>    6073      NaN
# 1         4  1                                    <p></p>    6073      NaN
# 2         4  1                                    <p></p>    6073      NaN
# 3         4  6                                        NaN   47632      NaN
# 4         2  4  <p> "spiritual songs" from Nicky Cook</p>    2710      NaN
#
#         ...        information interest language_code  \
# 0       ...                NaN     4656            en
# 1       ...                NaN     1470            en
# 2       ...                NaN     1933            en
# 3       ...                NaN    54881            en
# 4       ...                NaN      978            en
#
#                                              license listens lyricist number  \
# 0  Attribution-NonCommercial-ShareAlike 3.0 Inter...    1293      NaN      3
# 1  Attribution-NonCommercial-ShareAlike 3.0 Inter...     514      NaN      4
# 2  Attribution-NonCommercial-ShareAlike 3.0 Inter...    1151      NaN      6
# 3  Attribution-NonCommercial-NoDerivatives (aka M...   50135      NaN      1
# 4  Attribution-NonCommercial-NoDerivatives (aka M...     361      NaN      3
#
#   publisher tags            title
# 0       NaN   []             Food
# 1       NaN   []     Electric Ave
# 2       NaN   []       This World
# 3       NaN   []          Freeway
# 4       NaN   []  Spiritual Level
#
# [5 rows x 53 columns]
