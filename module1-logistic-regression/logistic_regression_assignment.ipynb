# %% [markdown]
# Assignment - real-world classification
#
# We're going to check out a larger dataset - the FMA Free Music Archive data. It has a selection of CSVs with metadata and calculated audio features that you can load and try to use to classify genre of tracks. To get you started:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
tracks = pd.read_csv("tracks.csv")
# Out:
# C:\Users\cwcol\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0,1,5,6,8,12,18,20,21,22,24,33,34,38,39,44,47,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
tracks.describe()
# Out:
#        Unnamed: 0   album              album.1              album.2  \
# count      106575  106575               103046                70295
# unique     106575      29                14341                 3670
# top         10610       0  2015-01-26 13:04:57  2008-01-01 00:00:00
# freq            1   71187                  310                  667
#
#                album.3  album.4  album.5  \
# count            15296   106575   106575
# unique             623       65    14929
# top     Ernie Indradat        0       -1
# freq               876    45753      805
#
#                                                   album.6  album.7  \
# count                                               83150   106575
# unique                                              11076    11351
# top     <p class="p1" style="margin: 0px; padding: 8px...       -1
# freq                                                  310     3130
#
#            album.8    ...     \
# count        18061    ...
# ...

# %%
pd.set_option('display.max_columns', None)  # Unlimited columns
tracks.head()
# Out:
#   Unnamed: 0     album              album.1              album.2   album.3  \
# 0        NaN  comments         date_created        date_released  engineer
# 1   track_id       NaN                  NaN                  NaN       NaN
# 2          2         0  2008-11-26 01:44:45  2009-01-05 00:00:00       NaN
# 3          3         0  2008-11-26 01:44:45  2009-01-05 00:00:00       NaN
# 4          5         0  2008-11-26 01:44:45  2009-01-05 00:00:00       NaN
#
#      album.4 album.5      album.6  album.7   album.8 album.9  \
# 0  favorites      id  information  listens  producer    tags
# 1        NaN     NaN          NaN      NaN       NaN     NaN
# 2          4       1      <p></p>     6073       NaN      []
# 3          4       1      <p></p>     6073       NaN      []
# 4          4       1      <p></p>     6073       NaN      []
#
#                album.10 album.11 album.12               artist  \
# 0                 title   tracks     type    active_year_begin
# ...

# %%
headers = tracks.iloc[0,:]
headers[0] = 'track_id'
tracks.columns = headers
tracks.drop([0,1], axis=0, inplace=True)

# %%
tracks.head()
# Out:
# 0 track_id comments         date_created        date_released engineer  \
# 2        2        0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 3        3        0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 4        5        0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 5       10        0  2008-11-26 01:45:08  2008-02-06 00:00:00      NaN
# 6       20        0  2008-11-26 01:45:05  2009-01-06 00:00:00      NaN
#
# 0 favorites id                                information listens producer  \
# 2         4  1                                    <p></p>    6073      NaN
# 3         4  1                                    <p></p>    6073      NaN
# 4         4  1                                    <p></p>    6073      NaN
# 5         4  6                                        NaN   47632      NaN
# 6         2  4  <p> "spiritual songs" from Nicky Cook</p>    2710      NaN
#
# 0 tags                 title tracks   type    active_year_begin  \
# ...

# %%
unique_producer = tracks["producer"].unique()

# %%
headers[1] = 'comments_album'
headers[5] = 'favorites_album'
headers[8] = 'listens_album'
headers[18] = 'comments_artist'
headers[20] = 'favorites_artist'
headers[34] = 'comments_track'
headers[39] = 'favorites_track'
headers[47] = 'listens_track'

tracks.columns = headers
tracks.head()
# Out:
# 0 track_id comments_album         date_created        date_released engineer  \
# 2        2              0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 3        3              0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 4        5              0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 5       10              0  2008-11-26 01:45:08  2008-02-06 00:00:00      NaN
# 6       20              0  2008-11-26 01:45:05  2009-01-06 00:00:00      NaN
#
# 0 favorites_album id                                information listens_album  \
# 2               4  1                                    <p></p>          6073
# 3               4  1                                    <p></p>          6073
# 4               4  1                                    <p></p>          6073
# 5               4  6                                        NaN         47632
# 6               2  4  <p> "spiritual songs" from Nicky Cook</p>          2710
#
# ...

# %%
features = ["comments_album","date_released","engineer","interest", "genres_all","composer","website"]

# %%
tracks["associated_labels"] = tracks["associated_labels"].replace(np.nan,"")

# %%
tracks["producer"] = tracks["producer"].replace(np.nan,"")

# %%
tracks["associated_labels"] = tracks["associated_labels"].apply(lambda x : x.split(",") if type(x)==str else x)

# %%
all_labels= []
tracks["associated_labels"]
for i in tracks["associated_labels"]:
    if type(i) == float:
        pass
    else:
        for j in i:
            all_labels.append(j)

# %%
all_labels_df = pd.DataFrame(all_labels, columns=["labels"])

# %%
all_labels_df.shape
# Out:
# (125235, 1)

# %%
unique_labels = all_labels_df["labels"].unique()

# %%
unique_labels.shape
# Out:
# (1281,)

# %%
labels = pd.DataFrame()
for i in unique_labels:
    labels[i] = tracks["associated_labels"].apply(lambda x : 1 if any(i in s for s in x) else 0)

# %%
all_genres = []

# %%
genres = pd.DataFrame()
for i in range(0,1235):
    genres[i] = tracks["genres_all"].apply(lambda x : 1 if any(str(i) in s for s in x) else 0)

# %%
producer = pd.DataFrame()
for i in unique_producer:
    producer[i] = tracks["producer"].apply(lambda x : 1 if any(str(i) in s for s in x) else 0)

# %%
x = pd.concat([producer,genres,labels,tracks["genre_top"]], axis =1)

# %%
x = x.dropna(subset=["genre_top"])

# %%
x.shape
# Out:
# (49598, 3278)

# %%
X= x.drop("genre_top",axis=1)
y = x["genre_top"]

log_reg = LogisticRegression().fit(X, y)
log_reg.score(X, y)
# Out:
# 0.8440461308923747

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=25)

# %%
principal_components = pca.fit_transform(X)

# %%
log_reg = LogisticRegression().fit(principal_components, y)

# %%
log_reg.score(principal_components,y)
# Out:
# 0.8363845316343401

# %%
pca = PCA(n_components=10)
principal_components = pca.fit_transform(X)
log_reg = LogisticRegression().fit(principal_components, y)
log_reg.score(principal_components,y)
# Out:
# 0.8078349933465059

# %%
X2 = pd.concat([producer,genres,labels,tracks[ ["genre_top","comments_album","date_released","engineer"\
                                              ,"interest", "genres_all","composer","website"] ]], axis =1)

# %%
X2["genre_top"]
# Out:
# 2              Hip-Hop
# 3              Hip-Hop
# 4              Hip-Hop
# 5                  Pop
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11             Hip-Hop
# 12                Rock
# 13                Rock
# 14        Experimental
# 15        Experimental
# 16                Folk
# 17                Folk
# 18                Folk
# 19                Folk
# 20                Jazz
# 21                Jazz
# 22                Jazz
# 23                Jazz
# 24        Experimental
# 25        Experimental
# 26        Experimental
# 27                Rock
# 28                Rock
# 29                Rock
# 30                Rock
# 31                Rock
#               ...
# 106546    Instrumental
# 106547    Instrumental
# 106548    Instrumental
# 106549    Instrumental
# 106550    Instrumental
# 106551    Instrumental
# 106552    Instrumental
# 106553    Instrumental
# 106554            Folk
# ...

# %%
X2 = X2.dropna(subset=["genre_top"])

# %%
X2.shape
# Out:
# (49598, 3284)

# %%
X2= X2.drop("genre_top",axis=1)
y = X2["genre_top"]

log_reg = LogisticRegression().fit(X2, y)
log_reg.score(X2, y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'genre_top'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-0327def2ba2d> in <module>()
#       1 X2= X2.drop("genre_top",axis=1)
# ...
